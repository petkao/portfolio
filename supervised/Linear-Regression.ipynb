# %% [markdown]
# Gradient Decent Autograd
# Linear Regression example:
# f(x) = w*x + b
# here: f(x) = 2 * x

# %%
import torch

# Linear regression
# f = w * x + b
# here : f = 2 * x

X = torch.tensor([1, 2, 3, 4, 5, 6, 7, 8], dtype=torch.float32)
Y = torch.tensor([2, 4, 6, 8, 10, 12, 14, 16], dtype=torch.float32)

w = torch.tensor(0.0, dtype=torch.float32, requires_grad=True)

# model output
def forward(x):
    return w * x

# loss = MSE
def loss(y, y_pred):
    return ((y_pred - y)**2).mean()

X_test = 5.0

print(f'Prediction before training:  f({X_test}) = {forward(X_test).item():.3f}')
# Out:
# Prediction before training:  f(5.0) = 0.000

# %%
# Training
learning_rate = 0.01
n_epochs = 100

for epoch in range(n_epochs):
  # predict = forward pass
  y_pred = forward(X)

  # loss
  l = loss(Y, y_pred)

  # Calcukate gradients = backward pass
  l.backward()

  # update weights
  # w.data = w.data - learning_rate * w.grad
  with torch.no_grad():
    w -= learning_rate * w.grad

  # zero the gradients ater updating
    w.grad.zero_()

  if epoch % 10 == 0:
    print(f'epoch {epoch+1}: w = {w:.3f}, loss = {l:.8f}')

  print(f'Prediction after training:  f({X_test}) = {forward(X_test).item():.3f}')
# Out:
# epoch 1: w = 1.020, loss = 102.00000000
# Prediction after training:  f(5.0) = 5.100
# Prediction after training:  f(5.0) = 7.599
# Prediction after training:  f(5.0) = 8.824
# Prediction after training:  f(5.0) = 9.424
# Prediction after training:  f(5.0) = 9.718
# Prediction after training:  f(5.0) = 9.862
# Prediction after training:  f(5.0) = 9.932
# Prediction after training:  f(5.0) = 9.967
# Prediction after training:  f(5.0) = 9.984
# Prediction after training:  f(5.0) = 9.992
# epoch 11: w = 1.999, loss = 0.00006494
# Prediction after training:  f(5.0) = 9.996
# Prediction after training:  f(5.0) = 9.998
# Prediction after training:  f(5.0) = 9.999
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 21: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 31: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 41: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 51: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 61: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 71: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 81: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# epoch 91: w = 2.000, loss = 0.00000000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
# Prediction after training:  f(5.0) = 10.000
